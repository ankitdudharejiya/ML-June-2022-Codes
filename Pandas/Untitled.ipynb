# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/student.csv')

# %%
df
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 4         1005     11          0           9.0                       3
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 7         1008     12         10           4.0                       8
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 10        1011     12          2           6.0                       2
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# ...

# %%
df
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 4         1005     11          0           9.0                       3
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 7         1008     12         10           4.0                       8
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 10        1011     12          2           6.0                       2
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/student.csv' , nrows=3)
df
# Out:
#    Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0        1001     10          2             8                       6
# 1        1002     10          6             5                       6
# 2        1003     10          3             6                       4
#
#    Moble Games hrs  Percentage
# 0                2          50
# 1                3          60
# 2                1          70

# %%
df.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeoing hrs',
#        'social media usage hrs', 'Moble Games hrs', 'Percentage'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
pd.read_csv()

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0        1001     10          2             8                       6
# 1        1002     10          6             5                       6
#
#    Moble Games hrs  Percentage
# 0                2          50
# 1                3          60

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0        1001     10          2             8                       6
#
#    Moble Games hrs  Percentage
# 0                2          50

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/student.csv' , usecols= [0,6])
df
# Out:
#     Student ID  Percentage
# 0         1001          50
# 1         1002          60
# 2         1003          70
# 3         1004          75
# 4         1005          65
# 5         1006          85
# 6         1007          95
# 7         1008         100
# 8         1009          95
# 9         1010          84
# 10        1011          87
# 11        1012          89

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10.csv' , skiprows = [4])
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   5        Techdrill               Health       2009  $10,573,990
# 4   6         Techline               Health       2006  $13,898,119
# 5   7          Cityace               Health       2010   $9,254,614
# 6   8   Kayelectronics               Health       2009   $9,451,943
# 7   9          Ganzlax          IT Services       2011  $14,001,180
# 8  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,435,363 Dollars   3138627     8%
# 4  5,470,303 Dollars   8427816    23%
# 5  6,249,498 Dollars   3005116     6%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10.csv' , index_col= 'Industry')
df
# Out:
#                      ID             Name  Inception       Revenue  \
# Industry
# IT Services           1          Lamtone       2009  $11,757,018
# Financial Services    2        Stripfind       2010  $12,329,371
# Health                3  Canecorporation       2012  $10,597,009
# IT Services           4         Mattouch       2013  $14,026,934
# Health                5        Techdrill       2009  $10,573,990
# Health                6         Techline       2006  $13,898,119
# Health                7          Cityace       2010   $9,254,614
# Health                8   Kayelectronics       2009   $9,451,943
# IT Services           9          Ganzlax       2011  $14,001,180
# Government Services  10      Trantraxlax       2011  $11,088,336
#
#                               Expenses    Profit Growth
# Industry
# IT Services          6,482,465 Dollars   5274553    30%
# Financial Services     916,455 Dollars  11412916    20%
# Health               7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_extra2.csv')
df
# Out:
#      0                1                    2          3             4  \
# 0   ID             Name             Industry  Inception       Revenue
# 1    1          Lamtone          IT Services       2009  $11,757,018
# 2    2        Stripfind   Financial Services       2010  $12,329,371
# 3    3  Canecorporation               Health       2012  $10,597,009
# 4    4         Mattouch          IT Services       2013  $14,026,934
# 5    5        Techdrill               Health       2009  $10,573,990
# 6    6         Techline               Health       2006  $13,898,119
# 7    7          Cityace               Health       2010   $9,254,614
# 8    8   Kayelectronics               Health       2009   $9,451,943
# 9    9          Ganzlax          IT Services       2011  $14,001,180
# 10  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     5         6       7
# 0            Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_extra2.csv' , skiprows=1)
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_nh.csv')
df
# Out:
#     1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2        Stripfind   Financial Services  2010  $12,329,371
# 1   3  Canecorporation               Health  2012  $10,597,009
# 2   4         Mattouch          IT Services  2013  $14,026,934
# 3   5        Techdrill               Health  2009  $10,573,990
# 4   6         Techline               Health  2006  $13,898,119
# 5   7          Cityace               Health  2010   $9,254,614
# 6   8   Kayelectronics               Health  2009   $9,451,943
# 7   9          Ganzlax          IT Services  2011  $14,001,180
# 8  10      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_nh.csv' , header = None)
df
# Out:
#     0                1                    2     3             4  \
# 0   1          Lamtone          IT Services  2009  $11,757,018
# 1   2        Stripfind   Financial Services  2010  $12,329,371
# 2   3  Canecorporation               Health  2012  $10,597,009
# 3   4         Mattouch          IT Services  2013  $14,026,934
# 4   5        Techdrill               Health  2009  $10,573,990
# 5   6         Techline               Health  2006  $13,898,119
# 6   7          Cityace               Health  2010   $9,254,614
# 7   8   Kayelectronics               Health  2009   $9,451,943
# 8   9          Ganzlax          IT Services  2011  $14,001,180
# 9  10      Trantraxlax  Government Services  2011  $11,088,336
#
#                    5         6    7
# 0  6,482,465 Dollars   5274553  30%
# 1    916,455 Dollars  11412916  20%
# 2  7,591,189 Dollars   3005820   7%
# 3  7,429,377 Dollars   6597557  26%
# 4  7,435,363 Dollars   3138627   8%
# 5  5,470,303 Dollars   8427816  23%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_nh.csv')
df
# Out:
#     1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2        Stripfind   Financial Services  2010  $12,329,371
# 1   3  Canecorporation               Health  2012  $10,597,009
# 2   4         Mattouch          IT Services  2013  $14,026,934
# 3   5        Techdrill               Health  2009  $10,573,990
# 4   6         Techline               Health  2006  $13,898,119
# 5   7          Cityace               Health  2010   $9,254,614
# 6   8   Kayelectronics               Health  2009   $9,451,943
# 7   9          Ganzlax          IT Services  2011  $14,001,180
# 8  10      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_nh.csv' , prefix= 'data' , header=None)
df
# Out:
#    data0            data1                data2  data3         data4  \
# 0      1          Lamtone          IT Services   2009  $11,757,018
# 1      2        Stripfind   Financial Services   2010  $12,329,371
# 2      3  Canecorporation               Health   2012  $10,597,009
# 3      4         Mattouch          IT Services   2013  $14,026,934
# 4      5        Techdrill               Health   2009  $10,573,990
# 5      6         Techline               Health   2006  $13,898,119
# 6      7          Cityace               Health   2010   $9,254,614
# 7      8   Kayelectronics               Health   2009   $9,451,943
# 8      9          Ganzlax          IT Services   2011  $14,001,180
# 9     10      Trantraxlax  Government Services   2011  $11,088,336
#
#                data5     data6 data7
# 0  6,482,465 Dollars   5274553   30%
# 1    916,455 Dollars  11412916   20%
# 2  7,591,189 Dollars   3005820    7%
# 3  7,429,377 Dollars   6597557   26%
# 4  7,435,363 Dollars   3138627    8%
# ...

# %%
ID,Name,Industry,Inception,Revenue,Expenses,Profit,Growth

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_nh.csv' , names = ['ID','Name','Industry','Inception','Revenue','Expenses','Profit','Growth'])
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/tags.csv')
df
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df.head(50)
# Out:
#     userId  movieId                          tag   timestamp
# 0        2    60756                        funny  1445714994
# 1        2    60756              Highly quotable  1445714996
# 2        2    60756                 will ferrell  1445714992
# 3        2    89774                 Boxing story  1445715207
# 4        2    89774                          MMA  1445715200
# 5        2    89774                    Tom Hardy  1445715205
# 6        2   106782                        drugs  1445715054
# 7        2   106782            Leonardo DiCaprio  1445715051
# 8        2   106782              Martin Scorsese  1445715056
# 9        7    48516                 way too long  1169687325
# 10      18      431                    Al Pacino  1462138765
# 11      18      431                     gangster  1462138749
# 12      18      431                        mafia  1462138755
# 13      18     1221                    Al Pacino  1461699306
# ...

# %%
df.tail()
# Out:
#       userId  movieId               tag   timestamp
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270

# %%
df.tail(10)
# Out:
#       userId  movieId               tag   timestamp
# 3673     606     1357             music  1176765393
# 3674     606     1948           British  1177512649
# 3675     606     3578            Romans  1173212944
# 3676     606     5694              70mm  1175638092
# 3677     606     6107      World War II  1178473747
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10.csv' , dtype= {'ID': 'float64'})
df
# Out:
#      ID             Name             Industry  Inception       Revenue  \
# 0   1.0          Lamtone          IT Services       2009  $11,757,018
# 1   2.0        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  Canecorporation               Health       2012  $10,597,009
# 3   4.0         Mattouch          IT Services       2013  $14,026,934
# 4   5.0        Techdrill               Health       2009  $10,573,990
# 5   6.0         Techline               Health       2006  $13,898,119
# 6   7.0          Cityace               Health       2010   $9,254,614
# 7   8.0   Kayelectronics               Health       2009   $9,451,943
# 8   9.0          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10.csv' , dtype= {'Profit': 'float64' , 'ID': "float64"})
df
# Out:
#      ID             Name             Industry  Inception       Revenue  \
# 0   1.0          Lamtone          IT Services       2009  $11,757,018
# 1   2.0        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  Canecorporation               Health       2012  $10,597,009
# 3   4.0         Mattouch          IT Services       2013  $14,026,934
# 4   5.0        Techdrill               Health       2009  $10,573,990
# 5   6.0         Techline               Health       2006  $13,898,119
# 6   7.0          Cityace               Health       2010   $9,254,614
# 7   8.0   Kayelectronics               Health       2009   $9,451,943
# 8   9.0          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   3005820.0     7%
# ...

# %%
df = pd.read_csv('C:/Users/bmbar/Desktop/Python Practise/Pandas/fortune_10_null.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False     False      False    False     False   False   False
# 1  False  False     False      False    False     False   False   False
# 2  False  False     False      False    False     False   False   False
# 3  False  False     False      False    False     False   False   False
# 4  False  False      True      False    False     False   False    True
# 5  False  False     False      False    False     False   False   False
# 6  False  False     False      False    False      True   False   False
# 7  False  False      True      False    False      True   False   False
# 8  False  False     False      False    False     False   False   False
# 9  False  False     False      False    False     False   False   False

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_drop.csv')

# %%
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.dropna(axis=1)
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   3138627

# %%
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.dropna( how= 'any')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna( how= 'all')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_ts.csv')

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(subset = ['Profit'])
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna()
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(inplace=False)
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df.dropna(subset = ['ID'])
